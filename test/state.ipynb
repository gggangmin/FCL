# %%
import numpy as np

# %%
def np_load(path):
    loaded = np.load(path, allow_pickle=True)
    return loaded

# %%
# 20230127-1258-fedweit-non_iid_50
client = np_load('../output/states/20230127-1258-fedweit-non_iid_50/0_client.npy')

# %%
client
# Out:
# array({'gpu_id': 0, 'client_id': 0, 'task_names': {0: 'cifar100_5_train', 1: 'cifar100_13_train', 2: 'face_scrub_0_train', 3: 'cifar100_14_train', 4: 'svhn_1_train', 5: 'traffic_sign_0_train', 6: 'not_mnist_1_train', 7: 'cifar100_8_train', 8: 'face_scrub_13_train', 9: 'cifar100_4_train'}, 'curr_task': 9, 'round_cnt': 2, 'done': False, 'curr_round': 29, 'prev_body_weights': {0: {0: array([[[[-1.13411255e-01, -3.04031856e-02, -1.29882842e-01, ...,
#           -1.74508092e-03, -8.70630443e-02,  6.87526241e-02],
#          [-1.50538504e-01,  1.05486135e-04, -6.70899078e-02, ...,
#            3.28806862e-02, -7.70947859e-02, -1.40275717e-01],
#          [ 5.17330840e-02,  1.25576675e-01,  8.42266455e-02, ...,
#            4.18085232e-02, -5.19293435e-02,  1.11640647e-01]],
#
#         [[-9.57197472e-02, -6.09675422e-03, -6.21503815e-02, ...,
#            3.33859632e-03,  8.71435106e-02, -2.10833661e-02],
#          [ 1.53162137e-01, -1.78997099e-01, -8.92447308e-02, ...,
# ...
