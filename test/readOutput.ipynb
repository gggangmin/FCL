# %%
import os

logDir_path = "/home/proj01/FCL/output/logs"
stateDir_path = "/home/proj01/FCL/output/states"

# %%
# client selection
import json
for directory in os.listdir(logDir_path):
    for f in os.listdir(os.path.join(logDir_path,directory)):
        print('file_name : ',f)
        client_file = open(os.path.join(logDir_path,directory,f),'r')
        client = json.loads(client_file.readlines()[0])
        print(client.keys())
        break
# Out:
# file_name :  client-1.txt
# dict_keys(['scores', 'capacity', 'communication', 'options'])

# %%
numRound = 10
for i in range(numRound):
    client['scores']['test_acc'][str(i)]

# %%
# draw accuracy plot
import numpy as np
import matplotlib.pyplot as plt
for i in range(10):
    plt.plot(client['scores']['test_acc'][str(i)])
    plt.ylabel('accuracy')
    plt.xlabel('Total number of round')
    plt.legend(range(10))
    plt.xticks(range(0,31,3))

# %%
file = open('../output/')
